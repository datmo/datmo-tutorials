# %% [markdown]
# `Fashion-MNIST` is a dataset of [Zalando](https://jobs.zalando.com/tech/)'s article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#
# Here's an example how the data looks (*each class takes three-rows*):
#
# ![](https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png)

# %% [markdown]
# This is a tutorial on fashion mnist dataset to show case a classifier along with datmo, in order to track our work and make machine learning workflow reproducible and usable. We have built classifiers for facial recognition, with very few images. The accuracy from this tutorial can be improved with more training images. You can also increase the number of classes or faces.
#
# This approach can be categorized into following methods,
#
# * Download the fashion MNIST dataset
# * Split the training and test data
# * Create a Convolution Neural Network architecture with 2 convolution layers
# * Create a Convolution Neural Network architecture with 3 convolution layers
# * Analyzing the results with the trained CNN
#
# During the process of model engineering, we would be using datmo to create versions of work by creating snapshot.

# %% [markdown]
# ### a. Download the fashion MNIST dataset

# %%
# Getting the Fashion MNIST data to local
import os
import requests, zipfile, StringIO

zip_file_url = 'https://s3-us-west-1.amazonaws.com/datmo-dataset-items/fashionmnist.zip'

r = requests.get(zip_file_url, stream=True)
z = zipfile.ZipFile(StringIO.StringIO(r.content))

input_dir = "data"
if not os.path.isdir(input_dir):
    os.mkdir(input_dir)
z.extractall(input_dir)
z.close()
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:318: SNIMissingWarning: An HTTPS request has been made, but the SNI (Subject Name Indication) extension to TLS is not available on this platform. This may cause the server to present an incorrect TLS certificate, which can cause validation failures. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/security.html#snimissingwarning.
#   SNIMissingWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:122: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "data"]).decode("utf8"))
# Out:
# fashion-mnist_test.csv
# fashion-mnist_train.csv
# t10k-images-idx3-ubyte
# t10k-labels-idx1-ubyte
# train-images-idx3-ubyte
# train-labels-idx1-ubyte

# %% [markdown]
# ### b. Split the training and test data
#
# In this work, we will train a CNN classifier using Keras with the guidelines described in [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python).
#
# We will be splitting 20% of the train data (12000 data rows) as a validation set to optimize the classifier, while keeping test data to finally evaluate the accuracy of the model on the data it has never seen.

# %%
from keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

data_train = pd.read_csv('data/fashion-mnist_train.csv')
data_test = pd.read_csv('data/fashion-mnist_test.csv')

img_rows, img_cols = 28, 28
input_shape = (img_rows, img_cols, 1)

X = np.array(data_train.iloc[:, 1:])
y = to_categorical(np.array(data_train.iloc[:, 0]))

# Here we split validation data to optimiza classifier during training
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=13)

#Test data
X_test = np.array(data_test.iloc[:, 1:])
y_test = to_categorical(np.array(data_test.iloc[:, 0]))



X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
X_val = X_val.reshape(X_val.shape[0], img_rows, img_cols, 1)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_val = X_val.astype('float32')
X_train /= 255
X_test /= 255
X_val /= 255
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### c. Create Convolution Neural Network architecture with 2 convolution layers

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint

batch_size = 256
num_classes = 10
epochs = 20

#input image dimensions
img_rows, img_cols = 28, 28

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 kernel_initializer='he_normal',
                 input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 128)       36992
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 15488)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               1982592
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 2,021,194
# Trainable params: 2,021,194
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### This training takes time based on hardware being used

# %%
# checkpoint
filepath="datmo_files/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val, y_val), callbacks=callbacks_list)
score = model.evaluate(X_test, y_test, verbose=0)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.5569 - acc: 0.7973Epoch 00000: val_acc improved from -inf to 0.86617, saving model to datmo_files/weights-improvement-00-0.87.hdf5
# 48000/48000 [==============================] - 31s - loss: 0.5562 - acc: 0.7976 - val_loss: 0.3664 - val_acc: 0.8662
# Epoch 2/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.3726 - acc: 0.8664Epoch 00001: val_acc improved from 0.86617 to 0.88325, saving model to datmo_files/weights-improvement-01-0.88.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.3724 - acc: 0.8665 - val_loss: 0.3181 - val_acc: 0.8833
# Epoch 3/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.3222 - acc: 0.8835Epoch 00002: val_acc improved from 0.88325 to 0.89417, saving model to datmo_files/weights-improvement-02-0.89.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.3222 - acc: 0.8835 - val_loss: 0.2854 - val_acc: 0.8942
# Epoch 4/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2879 - acc: 0.8956Epoch 00003: val_acc improved from 0.89417 to 0.89833, saving model to datmo_files/weights-improvement-03-0.90.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.2880 - acc: 0.8955 - val_loss: 0.2760 - val_acc: 0.8983
# Epoch 5/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2622 - acc: 0.9041Epoch 00004: val_acc improved from 0.89833 to 0.90933, saving model to datmo_files/weights-improvement-04-0.91.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.2624 - acc: 0.9040 - val_loss: 0.2489 - val_acc: 0.9093
# Epoch 6/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2451 - acc: 0.9102Epoch 00005: val_acc improved from 0.90933 to 0.91050, saving model to datmo_files/weights-improvement-05-0.91.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.2451 - acc: 0.9101 - val_loss: 0.2445 - val_acc: 0.9105
# Epoch 7/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2310 - acc: 0.9148Epoch 00006: val_acc did not improve
# 48000/48000 [==============================] - 33s - loss: 0.2311 - acc: 0.9147 - val_loss: 0.2506 - val_acc: 0.9075
# Epoch 8/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2178 - acc: 0.9185Epoch 00007: val_acc improved from 0.91050 to 0.91742, saving model to datmo_files/weights-improvement-07-0.92.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.2176 - acc: 0.9186 - val_loss: 0.2265 - val_acc: 0.9174
# Epoch 9/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2016 - acc: 0.9256Epoch 00008: val_acc did not improve
# 48000/48000 [==============================] - 33s - loss: 0.2021 - acc: 0.9255 - val_loss: 0.2254 - val_acc: 0.9172
# Epoch 10/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1909 - acc: 0.9281Epoch 00009: val_acc did not improve
# 48000/48000 [==============================] - 33s - loss: 0.1910 - acc: 0.9280 - val_loss: 0.2232 - val_acc: 0.9166
# Epoch 11/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1825 - acc: 0.9320Epoch 00010: val_acc improved from 0.91742 to 0.92217, saving model to datmo_files/weights-improvement-10-0.92.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.1825 - acc: 0.9320 - val_loss: 0.2158 - val_acc: 0.9222
# Epoch 12/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1736 - acc: 0.9340Epoch 00011: val_acc did not improve
# 48000/48000 [==============================] - 33s - loss: 0.1735 - acc: 0.9341 - val_loss: 0.2218 - val_acc: 0.9197
# Epoch 13/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1634 - acc: 0.9383Epoch 00012: val_acc improved from 0.92217 to 0.92242, saving model to datmo_files/weights-improvement-12-0.92.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.1633 - acc: 0.9384 - val_loss: 0.2195 - val_acc: 0.9224
# Epoch 14/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1546 - acc: 0.9410Epoch 00013: val_acc improved from 0.92242 to 0.92433, saving model to datmo_files/weights-improvement-13-0.92.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.1546 - acc: 0.9410 - val_loss: 0.2104 - val_acc: 0.9243
# Epoch 15/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1498 - acc: 0.9445Epoch 00014: val_acc did not improve
# 48000/48000 [==============================] - 33s - loss: 0.1500 - acc: 0.9444 - val_loss: 0.2191 - val_acc: 0.9222
# Epoch 16/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1438 - acc: 0.9455Epoch 00015: val_acc did not improve
# 48000/48000 [==============================] - 33s - loss: 0.1440 - acc: 0.9454 - val_loss: 0.2166 - val_acc: 0.9233
# Epoch 17/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1382 - acc: 0.9486Epoch 00016: val_acc did not improve
# 48000/48000 [==============================] - 33s - loss: 0.1381 - acc: 0.9486 - val_loss: 0.2155 - val_acc: 0.9231
# Epoch 18/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1310 - acc: 0.9507Epoch 00017: val_acc did not improve
# 48000/48000 [==============================] - 33s - loss: 0.1310 - acc: 0.9507 - val_loss: 0.2192 - val_acc: 0.9240
# Epoch 19/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1257 - acc: 0.9519Epoch 00018: val_acc improved from 0.92433 to 0.92500, saving model to datmo_files/weights-improvement-18-0.93.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.1258 - acc: 0.9519 - val_loss: 0.2226 - val_acc: 0.9250
# Epoch 20/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.1209 - acc: 0.9536Epoch 00019: val_acc improved from 0.92500 to 0.92583, saving model to datmo_files/weights-improvement-19-0.93.hdf5
# 48000/48000 [==============================] - 33s - loss: 0.1208 - acc: 0.9536 - val_loss: 0.2257 - val_acc: 0.9258

# %%
import json

print('Test loss:', score[0])
print('Test accuracy:', score[1])

config = {"loss":"categorical_crossentropy", "num_conv_layer": 2, "activation": "softmax", "fc_dim": 128}
stats = {'test_loss': score[0], 'test_accuracy': score[1]}

with open("config.json","w") as outfile:
    json.dump(config, outfile)

with open("stats.json", "w") as outfile:
    json.dump(stats, outfile)
# Out:
# ('Test loss:', 0.21457050281167031)
# ('Test accuracy:', 0.92769999999999997)

# %% [markdown]
# ### NOTE: SAVE YOUR JUPYTER NOTEBOOK HERE
#
# Creating a datmo snapshot to save my work until now, this helps me save my current work before proceeding onto changing our CNN architecture.
#
# Run this on your terminal to create a snapshot,
#
# ```bash
# home:~/datmo-tutorials/keras-fashion-mnist$ datmo snapshot create -m "2-conv-layer"
# Creating a new snapshot
# Created snapshot with id: 9095c50d30
# ```
#
# After running this, you should be able view the created snapshot using the command, snapshot ls
# ```bash
# home:~/datmo-tutorials/keras-fashion-mnist$ datmo snapshot ls
# +-------------+-----------+--------------------------------------+----------------+--------------+-------+
# |   id        | created at|               config                 |      stats     |    message   | label |
# +-------------+-----------+--------------------------------------+----------------+--------------+-------+
# | 9095c50d30  | 2018-06-03|   {"loss":"categorical_crossentropy",|{'test_loss':   | 2-conv-layer |  None |
# |             | 07:22:07  |    "num_conv_layer": 2,              | 0.203,         |              |       |
# |             |           |    "activation": "softmax",          |'test_accuracy':|              |       |
# |             |           |    "fc_dim": 128}                    | 0.929}         |              |       |
# +-------------+-----------+--------------------------------------+----------------+--------------+-------+
#
# ```

# %% [markdown]
# ### d. Create Convolution Neural Network architecture with 3 convolution layers

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint

batch_size = 256
num_classes = 10
epochs = 20

#input image dimensions
img_rows, img_cols = 28, 28

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 kernel_initializer='he_normal',
                 input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               147584
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 241,546
# Trainable params: 241,546
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### This training takes time based on hardware being used

# %%
# checkpoint
filepath="datmo_files/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val, y_val), callbacks=callbacks_list)
score = model.evaluate(X_test, y_test, verbose=0)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.8577 - acc: 0.6778Epoch 00000: val_acc improved from -inf to 0.80383, saving model to datmo_files/weights-improvement-00-0.80.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.8568 - acc: 0.6781 - val_loss: 0.5238 - val_acc: 0.8038
# Epoch 2/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.5169 - acc: 0.8080Epoch 00001: val_acc improved from 0.80383 to 0.84892, saving model to datmo_files/weights-improvement-01-0.85.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.5168 - acc: 0.8080 - val_loss: 0.4159 - val_acc: 0.8489
# Epoch 3/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.4436 - acc: 0.8379Epoch 00002: val_acc improved from 0.84892 to 0.86367, saving model to datmo_files/weights-improvement-02-0.86.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.4436 - acc: 0.8379 - val_loss: 0.3676 - val_acc: 0.8637
# Epoch 4/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.3964 - acc: 0.8547Epoch 00003: val_acc improved from 0.86367 to 0.87850, saving model to datmo_files/weights-improvement-03-0.88.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.3961 - acc: 0.8547 - val_loss: 0.3329 - val_acc: 0.8785
# Epoch 5/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.3725 - acc: 0.8640Epoch 00004: val_acc improved from 0.87850 to 0.88433, saving model to datmo_files/weights-improvement-04-0.88.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.3722 - acc: 0.8641 - val_loss: 0.3094 - val_acc: 0.8843
# Epoch 6/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.3481 - acc: 0.8743Epoch 00005: val_acc improved from 0.88433 to 0.88950, saving model to datmo_files/weights-improvement-05-0.89.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.3480 - acc: 0.8744 - val_loss: 0.3020 - val_acc: 0.8895
# Epoch 7/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.3295 - acc: 0.8796Epoch 00006: val_acc improved from 0.88950 to 0.89358, saving model to datmo_files/weights-improvement-06-0.89.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.3296 - acc: 0.8795 - val_loss: 0.2899 - val_acc: 0.8936
# Epoch 8/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.3181 - acc: 0.8838Epoch 00007: val_acc improved from 0.89358 to 0.89708, saving model to datmo_files/weights-improvement-07-0.90.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.3182 - acc: 0.8838 - val_loss: 0.2771 - val_acc: 0.8971
# Epoch 9/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.3057 - acc: 0.8867Epoch 00008: val_acc improved from 0.89708 to 0.90092, saving model to datmo_files/weights-improvement-08-0.90.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.3056 - acc: 0.8867 - val_loss: 0.2714 - val_acc: 0.9009
# Epoch 10/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2986 - acc: 0.8896Epoch 00009: val_acc improved from 0.90092 to 0.90275, saving model to datmo_files/weights-improvement-09-0.90.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.2988 - acc: 0.8895 - val_loss: 0.2646 - val_acc: 0.9028
# Epoch 11/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2875 - acc: 0.8952Epoch 00010: val_acc improved from 0.90275 to 0.90467, saving model to datmo_files/weights-improvement-10-0.90.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.2874 - acc: 0.8952 - val_loss: 0.2603 - val_acc: 0.9047
# Epoch 12/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2792 - acc: 0.8970Epoch 00011: val_acc improved from 0.90467 to 0.90717, saving model to datmo_files/weights-improvement-11-0.91.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.2792 - acc: 0.8969 - val_loss: 0.2507 - val_acc: 0.9072
# Epoch 13/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2747 - acc: 0.8988Epoch 00012: val_acc did not improve
# 48000/48000 [==============================] - 21s - loss: 0.2746 - acc: 0.8988 - val_loss: 0.2545 - val_acc: 0.9058
# Epoch 14/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2667 - acc: 0.9012Epoch 00013: val_acc improved from 0.90717 to 0.90808, saving model to datmo_files/weights-improvement-13-0.91.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.2667 - acc: 0.9011 - val_loss: 0.2514 - val_acc: 0.9081
# Epoch 15/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2597 - acc: 0.9031Epoch 00014: val_acc did not improve
# 48000/48000 [==============================] - 21s - loss: 0.2599 - acc: 0.9031 - val_loss: 0.2520 - val_acc: 0.9062
# Epoch 16/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2619 - acc: 0.9019Epoch 00015: val_acc improved from 0.90808 to 0.91217, saving model to datmo_files/weights-improvement-15-0.91.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.2616 - acc: 0.9020 - val_loss: 0.2403 - val_acc: 0.9122
# Epoch 17/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2516 - acc: 0.9059Epoch 00016: val_acc did not improve
# 48000/48000 [==============================] - 21s - loss: 0.2516 - acc: 0.9059 - val_loss: 0.2371 - val_acc: 0.9109
# Epoch 18/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2452 - acc: 0.9085Epoch 00017: val_acc improved from 0.91217 to 0.91292, saving model to datmo_files/weights-improvement-17-0.91.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.2453 - acc: 0.9085 - val_loss: 0.2372 - val_acc: 0.9129
# Epoch 19/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2411 - acc: 0.9097Epoch 00018: val_acc did not improve
# 48000/48000 [==============================] - 21s - loss: 0.2411 - acc: 0.9097 - val_loss: 0.2448 - val_acc: 0.9110
# Epoch 20/20
# 47872/48000 [============================>.] - ETA: 0s - loss: 0.2414 - acc: 0.9101Epoch 00019: val_acc improved from 0.91292 to 0.91600, saving model to datmo_files/weights-improvement-19-0.92.hdf5
# 48000/48000 [==============================] - 21s - loss: 0.2415 - acc: 0.9102 - val_loss: 0.2335 - val_acc: 0.9160

# %%
import json

print('Test loss:', score[0])
print('Test accuracy:', score[1])

config = {"loss":"categorical_crossentropy", "num_conv_layer": 3, "activation": "softmax", "fc_dim": 128}
stats = {'test_loss': score[0], 'test_accuracy': score[1]}

with open("config.json","w") as outfile:
    json.dump(config, outfile)

with open("stats.json", "w") as outfile:
    json.dump(stats, outfile)
# Out:
# ('Test loss:', 0.2153386633336544)
# ('Test accuracy:', 0.91990000000000005)

# %% [markdown]
# ### NOTE: SAVE YOUR JUPYTER NOTEBOOK HERE
#
# Creating a datmo snapshot to save my work with new architecture, this helps me save my current work before proceeding onto analyzing result.
#
# Run this on your terminal to create a snapshot,
#
# ```bash
# home:~/datmo-tutorials/keras-fashion-mnist$ datmo snapshot create -m "3-conv-layer"
# Creating a new snapshot
# Created snapshot with id: f106d61e41
# ```
#
# After running this, you should be able view the created snapshot using the command, snapshot ls
# ```bash
# home:~/datmo-tutorials/keras-fashion-mnist$ datmo snapshot ls
# +-------------+-----------+--------------------------------------+----------------+--------------+-------+
# |   id        | created at|               config                 |      stats     |    message   | label |
# +-------------+-----------+--------------------------------------+----------------+--------------+-------+
# | f106d61e41  | 2018-06-03|   {"loss":"categorical_crossentropy",|{'test_loss':   | 3-conv-layer |  None |
# |             | 08:22:07  |    "num_conv_layer": 3,              | 0.212,         |              |       |
# |             |           |    "activation": "softmax",          |'test_accuracy':|              |       |
# |             |           |    "fc_dim": 128}                    | 0.921}         |              |       |
# | 9095c50d30  | 2018-06-03|   {"loss":"categorical_crossentropy",|{'test_loss':   | 2-conv-layer |  None |
# |             | 07:22:07  |    "num_conv_layer": 2,              | 0.203,         |              |       |
# |             |           |    "activation": "softmax",          |'test_accuracy':|              |       |
# |             |           |    "fc_dim": 128}                    | 0.929}         |              |       |
# +-------------+-----------+--------------------------------------+----------------+--------------+-------+
#
# ```

# %% [markdown]
# ### e. Analyzing the results with the trained CNN

# %% [markdown]
# Let's plot training and validation accuracy as well as loss.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
accuracy = history.history['acc']
val_accuracy = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Classification Report
# We can summarize the performance of our classifier as follows

# %%
#get the predictions for the test data
predicted_classes = model.predict_classes(X_test)

#get the indices to be plotted
y_true = data_test.iloc[:, 0]
correct = np.nonzero(predicted_classes==y_true)[0]
incorrect = np.nonzero(predicted_classes!=y_true)[0]
# Out:
#  9888/10000 [============================>.] - ETA: 0s

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(num_classes)]
print(classification_report(y_true, predicted_classes, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     Class 0       0.85      0.89      0.87      1000
#     Class 1       0.99      0.99      0.99      1000
#     Class 2       0.92      0.84      0.88      1000
#     Class 3       0.94      0.93      0.93      1000
#     Class 4       0.83      0.93      0.88      1000
#     Class 5       0.99      0.97      0.98      1000
#     Class 6       0.78      0.73      0.76      1000
#     Class 7       0.94      0.97      0.96      1000
#     Class 8       0.99      0.98      0.99      1000
#     Class 9       0.97      0.97      0.97      1000
#
# avg / total       0.92      0.92      0.92     10000

# %% [markdown]
# It's apparent that our classifier is underperforming for class 6 in terms of both precision and recall. For class 2, classifier is slightly lacking precision whereas it is slightly lacking recall (i.e. missed) for class 4.
#
# Perhaps we would gain more insight after visualizing the correct and incorrect predictions.

# %% [markdown]
# Here is a subset of correctly predicted classes.

# %%
for i, correct in enumerate(correct[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_true[correct]))
    plt.tight_layout()

# %% [markdown]
# And here is a subset of incorrectly predicted classes.

# %%
for i, incorrect in enumerate(incorrect[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_true[incorrect]))
    plt.tight_layout()

# %% [markdown]
# It looks like diversity of the similar patterns present on multiple classes effect the performance of the classifier although CNN is a robust architechture. A jacket, a shirt, and a long-sleeve blouse has similar patterns: long sleeves (or not!), buttons (or not!), and so on.

# %% [markdown]
# #### What do the activations look like?
#
# The snippets are taken from _Chollet, F (2017)_. The idea is the give an input data and visualize the activations of the conv layers.

# %%
test_im = X_train[154]
plt.imshow(test_im.reshape(28,28), cmap='viridis', interpolation='none')
plt.show()

# %% [markdown]
# Let's see the activation of the 2nd channel of the first layer:

# %%
from keras import models
layer_outputs = [layer.output for layer in model.layers[:8]]
activation_model = models.Model(input=model.input, output=layer_outputs)
activations = activation_model.predict(test_im.reshape(1,28,28,1))

first_layer_activation = activations[0]
plt.matshow(first_layer_activation[0, :, :, 4], cmap='viridis')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[<tf.Tenso..., inputs=Tensor("co...)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# Let's plot the activations of the other conv layers as well.

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('conv'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in divide
#   from ipykernel import kernelapp as app
